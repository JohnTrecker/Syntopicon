# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from utils import retrieveMany

from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
# from sumy.summarizers.edmundson import EdmundsonSummarizer

# from sumy.nlp.stemmers import Stemmer
# import re

# description = 'Inferior deities or demigods in polytheistic religion'

summarizers = [LexRankSummarizer, LuhnSummarizer, LsaSummarizer, TextRankSummarizer]


text = retrieveMany(3, 100, 102)
parser = PlaintextParser.from_string(text, Tokenizer('english'))

print('=========')
summary = LexRankSummarizer(parser.document, 2)
for sentence in summary:
    print(sentence)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a87ed3b11146> in <module>()
#      21
#      22 print('=========')
# ---> 23 summary = LexRankSummarizer(parser.document, 2)
#      24 for sentence in summary:
#      25     print(sentence)
#
# TypeError: __init__() takes from 1 to 2 positional arguments but 3 were given

# %%
    # for Edmundson
# stemmer = Stemmer('english')
# summarizer = Summarizer(stemmer)
# description = ['deities', 'demigods', 'religion']
# summarizer.bonus_words = description
# summarizer.stigma_words = ['']
# summarizer.null_words = ['']

text = retrieveMany(3, 100, 102)
# text = text.split('.')[1:-1]
# text = '.'.join(text) + '.'
# text = re.sub('\[\d+\]\s', '', text)
# text = re.sub('\n', ' ', text)

for (method in methods)
parser = PlaintextParser.from_string(text, Tokenizer('english'))

summary = summarizer(parser.document, 2) 
for sentence in summary:
 print(sentence)

# %%
# import pandas as pd
# filename = '../data/csv/refs.csv'
# dic = pd.read_csv(filename, encoding='utf8')
# dic
# Out:
#           id  topic subtopic          author   vol alpha omega  \
# 0          1  Angel        1           Homer   3.0   167   171
# 1          2  Angel        1           Homer   3.0   174   179
# 2          3  Angel        1           Homer   3.0   228   230
# 3          4  Angel        1           Homer   3.0   244   NaN
# 4          5  Angel        1           Homer   3.0   258   261
# 5          6  Angel        1           Homer   3.0   350   353
# 6          7  Angel        1           Homer   3.0   388   389
# 7          8  Angel        1       Aeschylus   4.0    40    53
# 8          9  Angel        1       Aeschylus   4.0    90   103
# 9         10  Angel        1       Sophocles   4.0   216   233
# 10        11  Angel        1       Euripides   4.0   275   276
# 11        12  Angel        1       Euripides   4.0   296   315
# 12        13  Angel        1       Euripides   4.0   316   333
# 13        14  Angel        1       Euripides   4.0   363   365
# ...
